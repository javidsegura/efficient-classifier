# %%
import pandas as pd

# %%
PATH = "Extracted_Files/FinalDynamicDataset.csv"

# %%
df = pd.read_csv(PATH)
df.head()
# Out:
#    Memory_PssTotal  Memory_PssClean  Memory_SharedDirty  Memory_PrivateDirty  \
# 0            31053             2448               14044                23472
# 1           107787            21976               11852                74548
# 2            86584            18460               12284                59992
# 3            41248              924               10328                36280
# 4            38621             5080               12392                27388
#
#    Memory_SharedClean  Memory_PrivateClean  Memory_SwapPssDirty  \
# 0               74824                 2452                    0
# 1               69052                23152                    0
# 2               91548                19376                    0
# 3               55768                  928                    0
# 4               71048                 5088                    0
#
#    Memory_HeapSize  Memory_HeapAlloc  Memory_HeapFree  ...  Logcat_error  \
# 0             8919              4786             4132  ...          1635
# 1            25341             20965             4375  ...          1816
# 2            24500             21378             3121  ...          2244
# 3            10082              7281             2800  ...           974
# 4             9077              5750             3326  ...           936
#
#    Logcat_warning  Logcat_debug  Logcat_verbose  Logcat_total  Process_total  \
# 0            2351          3285            1551         11221            193
# 1             826          1544            2045          8457            189
# 2            3406          1565            2819         10780            195
# 3            4134          3138            1556         11739            191
# 4            2298          3752            1992         10488            188
#
#                                                 Hash    Category    Family  \
# 0  f460abb8f2e4e3fb689966ddaea6d6babbd1738bb691c7...  Trojan_SMS    opfake
# 1  556c238536d837007e647543eaf3ea95ae9aaf1c1a52d0...  Trojan_SMS    opfake
# 2  398322f94b5bfa2a9e7b3756a4cf409764595003280c48...  Trojan_SMS  fakeinst
# 3  4a9c14872b2c66165599a969a1a8654bb6887d7a18ab6d...  Trojan_SMS  fakeinst
# 4  6b37b9b9c170727f706b69731e64da4bbca2638b4237a7...  Trojan_SMS  fakeinst
#
#    reboot
# 0  before
# 1  before
# 2  before
# 3  before
# 4  before
#
# [5 rows x 145 columns]

# %%
df
# Out:
#        Memory_PssTotal  Memory_PssClean  Memory_SharedDirty  \
# 0                31053             2448               14044
# 1               107787            21976               11852
# 2                86584            18460               12284
# 3                41248              924               10328
# 4                38621             5080               12392
# ...                ...              ...                 ...
# 53434            54662             5068               12092
# 53435            30869             1972               11272
# 53436            39524             4608               12256
# 53437            27094             2664                9368
# 53438           112439            13000               10724
#
#        Memory_PrivateDirty  Memory_SharedClean  Memory_PrivateClean  \
# 0                    23472               74824                 2452
# 1                    74548               69052                23152
# 2                    59992               91548                19376
# 3                    36280               55768                  928
# 4                    27388               71048                 5088
# ...                    ...                 ...                  ...
# 53434                34996               97720                 9752
# 53435                23796               75888                 1988
# 53436                29620               65776                 4612
# 53437                19996               41916                 2672
# 53438                93456               79036                13576
#
#        Memory_SwapPssDirty  Memory_HeapSize  Memory_HeapAlloc  \
# 0                        0             8919              4786
# 1                        0            25341             20965
# 2                        0            24500             21378
# 3                        0            10082              7281
# 4                        0             9077              5750
# ...                    ...              ...               ...
# 53434                    0            20004             15914
# 53435                    0             7932              4867
# 53436                    0             7946              4840
# 53437                    0             8962              4290
# 53438                    0            45575             31323
#
#        Memory_HeapFree  ...  Logcat_error  Logcat_warning  Logcat_debug  \
# 0                 4132  ...          1635            2351          3285
# 1                 4375  ...          1816             826          1544
# 2                 3121  ...          2244            3406          1565
# 3                 2800  ...           974            4134          3138
# 4                 3326  ...           936            2298          3752
# ...                ...  ...           ...             ...           ...
# 53434             4089  ...          1871             904          2758
# 53435             3064  ...          4869            1563          9949
# 53436             3105  ...          1506            3028          8302
# 53437             4671  ...          1215            1525          2067
# 53438            14251  ...          1510            2808          1760
#
#        Logcat_verbose  Logcat_total  Process_total  \
# 0                1551         11221            193
# 1                2045          8457            189
# 2                2819         10780            195
# 3                1556         11739            191
# 4                1992         10488            188
# ...               ...           ...            ...
# 53434            2969         14612            186
# 53435            3365         21531            192
# 53436            1648         18595            188
# 53437            1732          7094            192
# 53438            3106         10279            193
#
#                                                     Hash    Category  \
# 0      f460abb8f2e4e3fb689966ddaea6d6babbd1738bb691c7...  Trojan_SMS
# 1      556c238536d837007e647543eaf3ea95ae9aaf1c1a52d0...  Trojan_SMS
# 2      398322f94b5bfa2a9e7b3756a4cf409764595003280c48...  Trojan_SMS
# 3      4a9c14872b2c66165599a969a1a8654bb6887d7a18ab6d...  Trojan_SMS
# 4      6b37b9b9c170727f706b69731e64da4bbca2638b4237a7...  Trojan_SMS
# ...                                                  ...         ...
# 53434  cb1b7b15172ecdf2ce7dc157798f188328fe4229680b48...         PUA
# 53435  2ba7cadbb1c86e3f1fcc72fafb6a787427a77c686995ab...         PUA
# 53436  774948489a4cba3c80fa481e4d47509911eded30106662...         PUA
# 53437  b6919cac1322f8625fbab614b304506229e93f4bcb1a3d...         PUA
# 53438  50126c6f36763e41ffecb9d3b623e07066ff494efb743a...         PUA
#
#          Family  reboot
# 0        opfake  before
# 1        opfake  before
# 2      fakeinst  before
# 3      fakeinst  before
# 4      fakeinst  before
# ...         ...     ...
# 53434     youmi  before
# 53435    secapk  before
# 53436    secapk  before
# 53437    secapk  before
# 53438   scamapp  before
#
# [53439 rows x 145 columns]

# %%
df.shape
# Out:
# (53439, 145)

# %%
df["Category"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %%
df["Family"].value_counts()
# Out:
# Family
# smsreg                                        8112
# skymobi                                       2857
# shedun                                        2631
# airpush                                       2017
# mytrackp                                      1940
#                                               ...
# SINGLETON:d7445193a7cb7f4141e15535b60d08ea       1
# SINGLETON:8e61088ece4d149576b2b3877e6147f8       1
# SINGLETON:ab64c9bae471b996330bcfdb3a170faa       1
# crytosh                                          1
# SINGLETON:ac1c7584923cd5cad18d23085d573b11       1
# Name: count, Length: 3078, dtype: int64

# %%
import matplotlib.pyplot as plt

df["Family"].value_counts().plot(kind="bar")
plt.xticks([])  # Remove x-axis labels
plt.xlabel("")   # Remove x-axis title (optional)
plt.show()
